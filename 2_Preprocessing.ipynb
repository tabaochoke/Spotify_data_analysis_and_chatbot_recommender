# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("1620_popular_songs.csv", encoding='utf-8')

# %%
df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.651   0.663    0    -5.569     0       0.0281        0.2280
# 1            0.507   0.394    6    -7.188     0       0.0350        0.5080
# 2            0.842   0.734    1    -5.065     0       0.0588        0.0427
# 3            0.759   0.561    0    -5.643     0       0.1310        0.8030
# 4            0.724   0.631    4    -4.420     0       0.0686        0.2490
# ...            ...     ...  ...       ...   ...          ...           ...
# 1615         0.687   0.792    5    -2.749     1       0.0452        0.1910
# 1616         0.932   0.457   11    -9.620     0       0.0541        0.0173
# 1617         0.776   0.831   11    -3.975     1       0.0457        0.3160
# 1618         0.294   0.641   11    -9.316     1       0.0291        0.0163
# 1619         0.784   0.826    7    -6.340     0       0.0538        0.0965
#
#       instrumentalness  liveness  valence  ...  time_signature popularity  \
# 0             0.000000    0.0994    0.465  ...               4         83
# 1             0.000000    0.0825    0.164  ...               4         85
# 2             0.000000    0.1060    0.952  ...               4         81
# 3             0.121000    0.1010    0.491  ...               4         82
# 4             0.000000    0.2130    0.957  ...               4         82
# ...                ...       ...      ...  ...             ...        ...
# 1615          0.000000    0.1670    0.671  ...               4         86
# 1616          0.043600    0.0414    0.884  ...               4         81
# 1617          0.000000    0.0688    0.891  ...               4         85
# 1618          0.220000    0.1120    0.226  ...               4         82
# 1619          0.000071    0.1230    0.893  ...               3         81
#
#                              song_name      artist_name genius_id  \
# 0        She Will Be Loved - Radio Mix         Maroon 5   9298707
# 1                  Shot Glass of Tears        Jung Kook   9626003
# 2                               Sucker   Jonas Brothers   4350998
# 3                         VISTA AL MAR          Quevedo   8357473
# 4                                WANDA          Quevedo   8719683
# ...                                ...              ...       ...
# 1615                           Happier       Marshmello   3792450
# 1616                       Billie Jean  Michael Jackson      1644
# 1617  Seven (feat. Latto) (Clean Ver.)        Jung Kook   8483479
# 1618                     November Rain    Guns N' Roses     84547
# 1619                               PRC       Peso Pluma   8736705
#
#                                  release_date  \
# 0                                         NaN
# 1       {'year': 2023, 'month': 11, 'day': 3}
# 2        {'year': 2019, 'month': 3, 'day': 1}
# 3        {'year': 2022, 'month': 9, 'day': 8}
# 4       {'year': 2023, 'month': 1, 'day': 20}
# ...                                       ...
# 1615    {'year': 2018, 'month': 8, 'day': 17}
# 1616   {'year': 1982, 'month': 11, 'day': 30}
# 1617  {'year': 2023, 'month': 7, 'day': None}
# 1618    {'year': 1991, 'month': 9, 'day': 17}
# 1619    {'year': 2023, 'month': 1, 'day': 24}
#
#                                                   lyric       tags  tier  \
# 0     <p>[Verse 1]<br>\nBeauty queen of only eightee...        pop     E
# 1     <p>[Chorus]<br>\nTell me, am I ever gonna feel...        pop     C
# 2     <p>[Verse 1: Nick Jonas]<br>\n<a href="/166176...        pop     D
# 3     <p>[Letra de "Vista Al Mar"]<br>\n<br>\n[Intro...        pop     E
# 4     <p>[Letra de "WANDA"]<br>\n<br>\n[Intro]<br>\n...        pop     E
# ...                                                 ...        ...   ...
# 1615  <p>[Intro]<br>\nLately, I've been, I've been t...        pop     D
# 1616  <p><a href="/10253695/Michael-jackson-billie-j...        pop     C
# 1617  <p><b>7/3</b><br>\nAJR - <a href="https://geni...  non-music     E
# 1618  <p>[Instrumental Intro]<br>\n<br>\n[Verse 1]<b...       rock     D
# 1619  <p>[Letra de "PRC"]<br>\n<br>\n[Verso 1: Peso ...        pop     D
#
#                                              genius_url
# 0     https://genius.com/Maroon-5-she-will-be-loved-...
# 1     https://genius.com/Jung-kook-shot-glass-of-tea...
# 2       https://genius.com/Jonas-brothers-sucker-lyrics
# 3        https://genius.com/Quevedo-vista-al-mar-lyrics
# 4               https://genius.com/Quevedo-wanda-lyrics
# ...                                                 ...
# 1615  https://genius.com/Marshmello-and-bastille-hap...
# 1616  https://genius.com/Michael-jackson-billie-jean...
# 1617  https://genius.com/Genius-july-2023-singles-re...
# 1618  https://genius.com/Guns-n-roses-november-rain-...
# 1619  https://genius.com/Peso-pluma-and-natanael-can...
#
# [1620 rows x 27 columns]

# %% [markdown]
# ## 1) Số dòng, cột data có:

# %%
n_rows, n_cols = df.shape
n_rows, n_cols
# Out:
# (1620, 27)

# %% [markdown]
# ## 2) Ý nghĩa các cột:

# %%
df.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature', 'popularity', 'song_name', 'artist_name', 'genius_id',
#        'release_date', 'lyric', 'tags', 'tier', 'genius_url'],
#       dtype='object')

# %%
len(df[df['type'] =='audio_features'])
# Out:
# 1620

# %% [markdown]
# - 'danceability' - Mức độ phù hợp của bài hát với việc nhảy múa trên thang tăng dần từ 0.0 tới 1.0, tức phù hợp trong những bữa tiệc.
#
# - 'energy' - Độ năng lượng của bài hát từ 0.0 tới 1.0. Bài hát có năng lượng cao được xét dựa trên cường độ của âm, tempo và nhiều thứ khác. Ví dụ, nhạc rock thường được xem là có năng lượng mạnh, trong khi nhạc đồng quê được xem là nhẹ nhàng.
#
# - 'key' - Tông của bài hát (Ví dụ : Đô trưởng, La thứ, ...)
#
# - 'loudness' - Cường độ âm thanh (theo thang dB).
#
# - 'mode' - Chế độ là âm trưởng hoặc thứ.
#
# - 'speechiness' - Mức độ hiện diện của giọng nói trên thang từ 0 tới 1. Ví dụ, podcast hoặc sách nói sẽ có speechiness cao, nhạc rap cũng mang xu hướng speechiness tương đối cao. Trong khi đó, những nhạc thông thường hoặc nhạc không lời sẽ có speechiness thấp.
#
# - 'acousticness' - Tính âm thanh của nhạc cụ. Có nghĩa là âm thanh được ghi trong bài đến từ âm thanh của các nhạc cụ không phải là nhạc được sản xuất bởi các âm thanh điện tử.
#
# - 'instrumentalness' - Tính nhạc cụ của bài hát. Tức là nếu bài hát có instrumentalness cao, nghĩa là ít vocal, tức là nhạc gốc không lời.
#
# - 'liveness' - Mức độ hiện diện của khán giả trong bài nhạc. Nếu có tiếng khán giả, tức giá trị cao thì chứng tỏ bài nhạc được hát trực tiếp chứ không phải ghi âm.
#
# - 'valence' - Giá trị tích cực với độ tích cực giảm dần từ 1.0 tới 0.0
#
# - 'tempo' - Nhịp, tính bằng số nhịp (beats) trên phút (BPM). Tempo càng cao thì nhạc càng nhanh.
#
# - 'type' - Loại của bài (Trong data tất cả là audio_features).
#
# - 'id' - Mã số bài hát trong Spotify
#
# - 'uri' - Định danh tài nguyên thống nhất
#
# - 'track_href' - Endpoint API của bài hát
#
# - 'analysis_url' - URL phân tích bài hát
#
# - 'duration_ms' - Thời lượng bài hát (theo miligiây)
#
# - 'time_signature' - Dấu thời gian. Tức số nhịp (beats) trên mỗi khung nhạc (bar)
#
# - 'popularity' - Độ phổ biến của bài hát trên thang 100
#
# - 'song_name' - Tên bài hát
#
# - 'artist_name' - Tên nghệ sĩ
#
# - 'genius_id' - Mã số của bài hát trên web Genius
#
# - 'release_date' - Ngày phát hành bài hát
#
# - 'lyric' - Lời bài hát
#
# - 'tags' - Thể loại của bài hát
#
# - 'tier' - Mức đánh giá chất lượng nhạc (A, B,C, D, E)
# - 'genius_url' - Đường dẫn bài nhạc trên Genius

# %% [markdown]
# ## 3) Check các dòng duplicated:

# %%
num_duplicated_rows = n_rows-len(df.drop_duplicates())
if num_duplicated_rows == 0:
    print(f"Data không có duplicate!")
else:
    print(f"Data có duplicate!")
# Out:
# Data không có duplicate!

# %% [markdown]
# ## 4) Các dạng dữ liệu của từng cột:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1620 entries, 0 to 1619
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      1620 non-null   float64
#  1   energy            1620 non-null   float64
#  2   key               1620 non-null   int64
#  3   loudness          1620 non-null   float64
#  4   mode              1620 non-null   int64
#  5   speechiness       1620 non-null   float64
#  6   acousticness      1620 non-null   float64
#  7   instrumentalness  1620 non-null   float64
#  8   liveness          1620 non-null   float64
#  9   valence           1620 non-null   float64
#  10  tempo             1620 non-null   float64
#  11  type              1620 non-null   object
#  12  id                1620 non-null   object
#  13  uri               1620 non-null   object
#  14  track_href        1620 non-null   object
#  15  analysis_url      1620 non-null   object
#  16  duration_ms       1620 non-null   int64
#  17  time_signature    1620 non-null   int64
#  18  popularity        1620 non-null   int64
#  19  song_name         1620 non-null   object
#  20  artist_name       1620 non-null   object
#  21  genius_id         1620 non-null   int64
#  22  release_date      1556 non-null   object
#  23  lyric             1619 non-null   object
#  24  tags              1620 non-null   object
#  25  tier              1620 non-null   object
#  26  genius_url        1620 non-null   object
# dtypes: float64(9), int64(6), object(12)
# memory usage: 341.8+ KB

# %% [markdown]
# Không có cột có kiểu dữ liệu sai. Genres và released_date đang ở dạng string, khiến việc xử lí data trở nên phức tạp.
# - Released_date : Đổi về dạng dictionary, sau đó trích ra cột released_year với kiểu dữ liệu int.

# %%
def get_year(date_string):
    return int(date_string.split(":")[1].split(",")[0])

# %%
df['released_year'] = df['release_date'].apply(lambda x: get_year(x) if not pd.isnull(x) else np.nan)

# %% [markdown]
# Loại bỏ cột "release_date"

# %%
df = df.drop(["release_date"],axis=1)

# %% [markdown]
# ## 5) Phân bố data:

# %% [markdown]
# 5.1) Data dạng số:

# %%
num_col_info_df = df.select_dtypes(np.number)
def missing_ratio(input):
    return (input.isnull().sum() / len(input) * 100).round(1)
def lower_quartile(input):
    return input.dropna().quantile(0.25).round(1)
def median(input):
    return input.dropna().quantile(0.50).round(1)
def upper_quartile(input):
    return input.dropna().quantile(0.75).round(1)
num_col_info_df = num_col_info_df.agg([missing_ratio, "min", lower_quartile, median, upper_quartile, "max"])
num_col_info_df
# Out:
#                 danceability   energy   key  loudness  mode  speechiness  \
# missing_ratio          0.000  0.00000   0.0     0.000   0.0        0.000
# min                    0.000  0.00342   0.0   -38.151   0.0        0.000
# lower_quartile         0.500  0.50000   2.0    -8.300   0.0        0.000
# median                 0.600  0.60000   5.0    -6.300   1.0        0.100
# upper_quartile         0.700  0.80000   8.0    -4.800   1.0        0.100
# max                    0.969  0.99000  11.0    -0.514   1.0        0.591
#
#                 acousticness  instrumentalness  liveness  valence    tempo  \
# missing_ratio       0.000000               0.0    0.0000    0.000    0.000
# min                 0.000008               0.0    0.0232    0.000    0.000
# lower_quartile      0.000000               0.0    0.1000    0.300   98.600
# median              0.200000               0.0    0.1000    0.500  120.400
# upper_quartile      0.400000               0.0    0.2000    0.700  140.000
# max                 0.994000               1.0    0.8810    0.981  210.164
#
#                 duration_ms  time_signature  popularity  genius_id  \
# missing_ratio           0.0             0.0         0.0        0.0
# min                 57370.0             0.0        80.0       -1.0
# lower_quartile     174842.0             4.0        81.0   511538.5
# median             205673.0             4.0        83.0  4274795.5
# upper_quartile     237095.2             4.0        86.0  8483479.0
# max                613027.0             5.0       100.0  9840200.0
#
#                 released_year
# missing_ratio             4.0
# min                       0.0
# lower_quartile         2012.0
# median                 2018.0
# upper_quartile         2022.0
# max                    2023.0

# %% [markdown]
# 5.1.1) Cột dữ liệu released_year có những dòng missing_value, điều này ảnh hưởng cho phân tích dữ liệu sau này, loại bỏ các dòng ấy:

# %%
df = df[df['released_year'].notnull()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1556 entries, 1 to 1619
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      1556 non-null   float64
#  1   energy            1556 non-null   float64
#  2   key               1556 non-null   int64
#  3   loudness          1556 non-null   float64
#  4   mode              1556 non-null   int64
#  5   speechiness       1556 non-null   float64
#  6   acousticness      1556 non-null   float64
#  7   instrumentalness  1556 non-null   float64
#  8   liveness          1556 non-null   float64
#  9   valence           1556 non-null   float64
#  10  tempo             1556 non-null   float64
#  11  type              1556 non-null   object
#  12  id                1556 non-null   object
#  13  uri               1556 non-null   object
#  14  track_href        1556 non-null   object
#  15  analysis_url      1556 non-null   object
#  16  duration_ms       1556 non-null   int64
#  17  time_signature    1556 non-null   int64
#  18  popularity        1556 non-null   int64
#  19  song_name         1556 non-null   object
#  20  artist_name       1556 non-null   object
#  21  genius_id         1556 non-null   int64
#  22  lyric             1556 non-null   object
#  23  tags              1556 non-null   object
#  24  tier              1556 non-null   object
#  25  genius_url        1556 non-null   object
#  26  released_year     1556 non-null   float64
# dtypes: float64(10), int64(6), object(11)
# memory usage: 340.4+ KB

# %%
df[df['released_year'] == 0]
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 121          0.357   0.668    0    -8.444     1       0.0479        0.3620
# 141          0.356   0.917    9    -6.006     1       0.0479        0.0335
# 156          0.418   0.106    8   -22.507     0       0.0448        0.9940
# 249          0.512   0.339    8   -13.119     1       0.0498        0.7270
# 257          0.321   0.640    2   -10.023     1       0.0324        0.2800
# 262          0.262   0.137    8   -15.235     1       0.0344        0.9130
# 263          0.834   0.371    1   -11.990     1       0.0358        0.7990
# 273          0.521   0.366   11    -7.698     0       0.0340        0.8380
# 396          0.518   0.368   11    -7.760     0       0.0353        0.8550
# 408          0.553   0.476    0    -8.869     1       0.0649        0.6470
# 633          0.692   0.711    0    -7.498     0       0.0317        0.2250
# 652          0.607   0.103    9   -14.405     1       0.0404        0.8040
# 851          0.724   0.276    7   -12.250     1       0.0599        0.7600
# 1108         0.724   0.684   11    -4.413     1       0.0705        0.1440
# 1240         0.165   0.266    8   -38.151     1       0.1350        0.8150
# 1501         0.711   0.718    1    -5.671     1       0.0994        0.3790
# 1506         0.564   0.932   11   -10.068     1       0.0554        0.0130
# 1604         0.647   0.822    5    -4.662     0       0.1830        0.2190
#
#       instrumentalness  liveness  valence  ...  time_signature popularity  \
# 121           0.000001    0.7270   0.4070  ...               4         85
# 141           0.000000    0.4060   0.5180  ...               4         82
# 156           0.029200    0.1790   0.8000  ...               4         84
# 249           0.000000    0.0977   0.9510  ...               4         87
# 257           0.000000    0.7180   0.4140  ...               3         91
# 262           0.000007    0.2670   0.2880  ...               3         84
# 263           0.000000    0.2750   0.9760  ...               4         85
# 273           0.000004    0.1200   0.2250  ...               4         89
# 396           0.000005    0.1190   0.2340  ...               4         85
# 408           0.000000    0.2810   0.5580  ...               3         83
# 633           0.000000    0.1200   0.8750  ...               4         85
# 652           0.000000    0.0760   0.3410  ...               4         81
# 851           0.000000    0.1160   0.7180  ...               4         89
# 1108          0.003500    0.3020   0.7290  ...               3         82
# 1240          0.901000    0.0992   0.0267  ...               4         82
# 1501          0.000000    0.1190   0.6890  ...               4         84
# 1506          0.169000    0.3490   0.6190  ...               4         81
# 1604          0.000000    0.0908   0.9620  ...               4         82
#
#                                               song_name  \
# 121   Santa Claus Is Comin' to Town - Live at C.W. P...
# 141             Bitter Sweet Symphony - Remastered 2016
# 156                                  Carol of the Bells
# 249                      Jingle Bells - Remastered 1999
# 257          Happy Xmas (War Is Over) - Remastered 2010
# 262   Have Yourself A Merry Little Christmas - Remas...
# 263   Here Comes Santa Claus (Right Down Santa Claus...
# 273   Can’t Catch Me Now - from The Hunger Games: Th...
# 396   Can’t Catch Me Now - from The Hunger Games: Th...
# 408         Baby It's Cold Outside (with Michael Bublé)
# 633        Sweet Dreams (Are Made of This) - Remastered
# 652               Mistletoe And Holly - Remastered 1999
# 851   It's Beginning to Look a Lot Like Christmas (w...
# 1108                                         El Gavilán
# 1240               Relaxing Brown Noise 256 Hz Smooth Q
# 1501                      Narcotics (with Bryant Myers)
# 1506                          Immigrant Song - Remaster
# 1604                     Happy - From "Despicable Me 2"
#
#                        artist_name genius_id lyric  tags  tier  \
# 121              Bruce Springsteen        -1     0     0     0
# 141                      The Verve        -1     0     0     0
# 156   Mykola Dmytrovych Leontovych        -1     0     0     0
# 249                  Frank Sinatra        -1     0     0     0
# 257                    John Lennon        -1     0     0     0
# 262                  Frank Sinatra        -1     0     0     0
# 263                     Gene Autry        -1     0     0     0
# 273                 Olivia Rodrigo        -1     0     0     0
# 396                 Olivia Rodrigo        -1     0     0     0
# 408                   Idina Menzel        -1     0     0     0
# 633                     Eurythmics        -1     0     0     0
# 652                  Frank Sinatra        -1     0     0     0
# 851                     Perry Como        -1     0     0     0
# 1108              Luis R Conriquez        -1     0     0     0
# 1240                    Jane Color        -1     0     0     0
# 1501                         Dei V        -1     0     0     0
# 1506                  Led Zeppelin        -1     0     0     0
# 1604             Pharrell Williams        -1     0     0     0
#
#                                              genius_url released_year
# 121                                                  -1           0.0
# 141                                                  -1           0.0
# 156                                                  -1           0.0
# 249                                                  -1           0.0
# 257                                                  -1           0.0
# 262                                                  -1           0.0
# 263                                                  -1           0.0
# 273                                                  -1           0.0
# 396                                                  -1           0.0
# 408                                                  -1           0.0
# 633                                                  -1           0.0
# 652                                                  -1           0.0
# 851                                                  -1           0.0
# 1108  https://genius.com/Genius-en-espanol-discograf...           0.0
# 1240                                                 -1           0.0
# 1501                                                 -1           0.0
# 1506                                                 -1           0.0
# 1604                                                 -1           0.0
#
# [18 rows x 27 columns]

# %% [markdown]
# Sau khi lọc null release_date, ta cũng lọc được giá trị lyric null. Bây giờ ta có bài hát với dữ liệu đầy đủ.

# %% [markdown]
# 5.1.2) Có genius_id không hợp lệ. Loại bỏ những dòng có id không hợp lệ

# %%
df = df[df['genius_id'] > 0].reset_index(drop = True)

# %%
num_col_info_df = df.select_dtypes(np.number)
num_col_info_df = num_col_info_df.agg([missing_ratio, "min", lower_quartile, median, upper_quartile, "max"])
num_col_info_df
# Out:
#                 danceability   energy   key  loudness  mode  speechiness  \
# missing_ratio          0.000  0.00000   0.0     0.000   0.0        0.000
# min                    0.000  0.00342   0.0   -28.460   0.0        0.000
# lower_quartile         0.500  0.50000   2.0    -8.300   0.0        0.000
# median                 0.600  0.70000   5.0    -6.300   1.0        0.100
# upper_quartile         0.700  0.80000   8.0    -4.800   1.0        0.100
# max                    0.969  0.99000  11.0    -0.514   1.0        0.591
#
#                 acousticness  instrumentalness  liveness  valence    tempo  \
# missing_ratio       0.000000               0.0    0.0000    0.000    0.000
# min                 0.000008               0.0    0.0232    0.000    0.000
# lower_quartile      0.000000               0.0    0.1000    0.300   98.900
# median              0.200000               0.0    0.1000    0.500  120.900
# upper_quartile      0.400000               0.0    0.2000    0.700  140.000
# max                 0.989000               1.0    0.8810    0.981  210.164
#
#                 duration_ms  time_signature  popularity  genius_id  \
# missing_ratio           0.0             0.0         0.0        0.0
# min                 57370.0             0.0        80.0       74.0
# lower_quartile     175189.2             4.0        81.0   528021.5
# median             206240.0             4.0        83.0  4327249.0
# upper_quartile     237528.0             4.0        86.0  8485914.8
# max                613027.0             5.0       100.0  9840200.0
#
#                 released_year
# missing_ratio             0.0
# min                    1909.0
# lower_quartile         2013.0
# median                 2019.0
# upper_quartile         2022.0
# max                    2023.0

# %% [markdown]
# 5.2) Data không phải dạng số:

# %%
cat_col_info_df = df.select_dtypes(include='object')

def missing_ratio(input):
    return (input.isnull().sum() / len(input) * 100).round(1)
def num_values(input):
    return input.dropna().nunique()
def value_ratios(input):
    value_ratio = (input.value_counts() / len(input) * 100).round(1)
    return value_ratio.to_dict()

cat_col_info_df = cat_col_info_df.agg([missing_ratio, num_values, value_ratios])
cat_col_info_df
# Out:
#                                     type  \
# missing_ratio                        0.0
# num_values                             1
# value_ratios   {'audio_features': 100.0}
#
#                                                               id  \
# missing_ratio                                                0.0
# num_values                                                  1538
# value_ratios   {'7AbqgE05nFl9qY4FRUiq2p': 0.1, '4HBZA5flZLE43...
#
#                                                              uri  \
# missing_ratio                                                0.0
# num_values                                                  1538
# value_ratios   {'spotify:track:7AbqgE05nFl9qY4FRUiq2p': 0.1, ...
#
#                                                       track_href  \
# missing_ratio                                                0.0
# num_values                                                  1538
# value_ratios   {'https://api.spotify.com/v1/tracks/7AbqgE05nF...
#
#                                                     analysis_url  \
# missing_ratio                                                0.0
# num_values                                                  1538
# value_ratios   {'https://api.spotify.com/v1/audio-analysis/7A...
#
#                                                        song_name  \
# missing_ratio                                                0.0
# num_values                                                  1473
# value_ratios   {'Christmas (Baby Please Come Home)': 0.2, 'Sl...
#
#                                                      artist_name  \
# missing_ratio                                                0.0
# num_values                                                   627
# value_ratios   {'Taylor Swift': 5.8, 'Bad Bunny': 2.2, 'Drake...
#
#                                                            lyric  \
# missing_ratio                                                0.0
# num_values                                                  1466
# value_ratios   {'0': 0.5, '<p>1. Post Malone- Circles<br>
# 2. ...
#
#                                                             tags  \
# missing_ratio                                                0.0
# num_values                                                     7
# value_ratios   {'pop': 45.8, 'rap': 17.6, 'rock': 16.6, 'r-b'...
#
#                                                             tier  \
# missing_ratio                                                0.0
# num_values                                                     6
# value_ratios   {'D': 55.8, 'C': 20.2, 'E': 19.3, 'B': 4.0, '0...
#
#                                                       genius_url
# missing_ratio                                                0.0
# num_values                                                  1473
# value_ratios   {'https://genius.com/Spotify-this-is-post-malo...

# %% [markdown]
# Tồn tại missing value ở lyric. Loại bỏ các dòng có lyric có giá trị NaN, tức == '0' (do quá trình lấy dữ liệu sử dụng hàm để set các giá trị):

# %%
df = df[df['lyric'] != '0'].reset_index()
df = df.drop(['index'],axis=1)

# %%
df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.507   0.394    6    -7.188     0       0.0350        0.5080
# 1            0.842   0.734    1    -5.065     0       0.0588        0.0427
# 2            0.759   0.561    0    -5.643     0       0.1310        0.8030
# 3            0.724   0.631    4    -4.420     0       0.0686        0.2490
# 4            0.765   0.356   11    -5.556     0       0.1950        0.2230
# ...            ...     ...  ...       ...   ...          ...           ...
# 1526         0.687   0.792    5    -2.749     1       0.0452        0.1910
# 1527         0.932   0.457   11    -9.620     0       0.0541        0.0173
# 1528         0.776   0.831   11    -3.975     1       0.0457        0.3160
# 1529         0.294   0.641   11    -9.316     1       0.0291        0.0163
# 1530         0.784   0.826    7    -6.340     0       0.0538        0.0965
#
#       instrumentalness  liveness  valence  ...  time_signature popularity  \
# 0             0.000000    0.0825    0.164  ...               4         85
# 1             0.000000    0.1060    0.952  ...               4         81
# 2             0.121000    0.1010    0.491  ...               4         82
# 3             0.000000    0.2130    0.957  ...               4         82
# 4             0.000000    0.0963    0.189  ...               4         86
# ...                ...       ...      ...  ...             ...        ...
# 1526          0.000000    0.1670    0.671  ...               4         86
# 1527          0.043600    0.0414    0.884  ...               4         81
# 1528          0.000000    0.0688    0.891  ...               4         85
# 1529          0.220000    0.1120    0.226  ...               4         82
# 1530          0.000071    0.1230    0.893  ...               3         81
#
#                              song_name      artist_name genius_id  \
# 0                  Shot Glass of Tears        Jung Kook   9626003
# 1                               Sucker   Jonas Brothers   4350998
# 2                         VISTA AL MAR          Quevedo   8357473
# 3                                WANDA          Quevedo   8719683
# 4                                Don't    Bryson Tiller    579968
# ...                                ...              ...       ...
# 1526                           Happier       Marshmello   3792450
# 1527                       Billie Jean  Michael Jackson      1644
# 1528  Seven (feat. Latto) (Clean Ver.)        Jung Kook   8483479
# 1529                     November Rain    Guns N' Roses     84547
# 1530                               PRC       Peso Pluma   8736705
#
#                                                   lyric       tags  tier  \
# 0     <p>[Chorus]<br>\nTell me, am I ever gonna feel...        pop     C
# 1     <p>[Verse 1: Nick Jonas]<br>\n<a href="/166176...        pop     D
# 2     <p>[Letra de "Vista Al Mar"]<br>\n<br>\n[Intro...        pop     E
# 3     <p>[Letra de "WANDA"]<br>\n<br>\n[Intro]<br>\n...        pop     E
# 4     <p><a href="/7902499/Bryson-tiller-dont/Verse-...        r-b     C
# ...                                                 ...        ...   ...
# 1526  <p>[Intro]<br>\nLately, I've been, I've been t...        pop     D
# 1527  <p><a href="/10253695/Michael-jackson-billie-j...        pop     C
# 1528  <p><b>7/3</b><br>\nAJR - <a href="https://geni...  non-music     E
# 1529  <p>[Instrumental Intro]<br>\n<br>\n[Verse 1]<b...       rock     D
# 1530  <p>[Letra de "PRC"]<br>\n<br>\n[Verso 1: Peso ...        pop     D
#
#                                              genius_url released_year
# 0     https://genius.com/Jung-kook-shot-glass-of-tea...        2023.0
# 1       https://genius.com/Jonas-brothers-sucker-lyrics        2019.0
# 2        https://genius.com/Quevedo-vista-al-mar-lyrics        2022.0
# 3               https://genius.com/Quevedo-wanda-lyrics        2023.0
# 4          https://genius.com/Bryson-tiller-dont-lyrics        2014.0
# ...                                                 ...           ...
# 1526  https://genius.com/Marshmello-and-bastille-hap...        2018.0
# 1527  https://genius.com/Michael-jackson-billie-jean...        1982.0
# 1528  https://genius.com/Genius-july-2023-singles-re...        2023.0
# 1529  https://genius.com/Guns-n-roses-november-rain-...        1991.0
# 1530  https://genius.com/Peso-pluma-and-natanael-can...        2023.0
#
# [1531 rows x 27 columns]

# %% [markdown]
# Bên cạnh đó, API lúc truy cập có thể dẫn tới sai sót, nên ra những tags non-music.

# %%
df = df[df['tags'] != 'non-music']

# %%
cat_col_info_df = df.select_dtypes(include='object')
cat_col_info_df = cat_col_info_df.agg([missing_ratio, num_values, value_ratios])
cat_col_info_df
# Out:
#                                     type  \
# missing_ratio                        0.0
# num_values                             1
# value_ratios   {'audio_features': 100.0}
#
#                                                               id  \
# missing_ratio                                                0.0
# num_values                                                  1453
# value_ratios   {'7AbqgE05nFl9qY4FRUiq2p': 0.1, '6Nle9hKrkL1wQ...
#
#                                                              uri  \
# missing_ratio                                                0.0
# num_values                                                  1453
# value_ratios   {'spotify:track:7AbqgE05nFl9qY4FRUiq2p': 0.1, ...
#
#                                                       track_href  \
# missing_ratio                                                0.0
# num_values                                                  1453
# value_ratios   {'https://api.spotify.com/v1/tracks/7AbqgE05nF...
#
#                                                     analysis_url  \
# missing_ratio                                                0.0
# num_values                                                  1453
# value_ratios   {'https://api.spotify.com/v1/audio-analysis/7A...
#
#                                                        song_name  \
# missing_ratio                                                0.0
# num_values                                                  1392
# value_ratios   {'Christmas (Baby Please Come Home)': 0.2, 'Di...
#
#                                                      artist_name  \
# missing_ratio                                                0.0
# num_values                                                   602
# value_ratios   {'Taylor Swift': 6.1, 'Bad Bunny': 2.3, 'The W...
#
#                                                            lyric  \
# missing_ratio                                                0.0
# num_values                                                  1398
# value_ratios   {'<p>1. Post Malone- Circles<br>
# 2. Post Malon...
#
#                                                             tags  \
# missing_ratio                                                0.0
# num_values                                                     5
# value_ratios   {'pop': 48.5, 'rap': 18.6, 'rock': 17.5, 'r-b'...
#
#                                                             tier  \
# missing_ratio                                                0.0
# num_values                                                     5
# value_ratios   {'D': 59.0, 'C': 21.4, 'E': 15.1, 'B': 4.2, 'A...
#
#                                                       genius_url
# missing_ratio                                                0.0
# num_values                                                  1400
# value_ratios   {'https://genius.com/Spotify-this-is-post-malo...

# %% [markdown]
# ## 6) Xử lí cột 'lyric':

# %%
from bs4 import BeautifulSoup
import re

# %%
def lyric_cleanser(lyric):
  soup = BeautifulSoup(lyric, 'html.parser')
  clean_lyric = soup.get_text()
  clean_lyric = re.sub(r'\[.*?\]', '', clean_lyric)
  clean_lyric = re.sub(r'\n', ' ', clean_lyric)
  clean_lyric = re.sub(r'\s+', ' ', clean_lyric)
  return clean_lyric

# %%
df['lyric'] = df['lyric'].apply(lambda x: lyric_cleanser(x))
# Out:
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_26400\852511084.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lyric'] = df['lyric'].apply(lambda x: lyric_cleanser(x))

# %% [markdown]
# ## 7) Loại bỏ những cột thừa sau khi đã xử lí xong dữ liệu :

# %%
df.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature', 'popularity', 'song_name', 'artist_name', 'genius_id',
#        'lyric', 'tags', 'tier', 'genius_url', 'released_year'],
#       dtype='object')

# %% [markdown]
# Những cột type, uri, track_href, analysis_url có tác dụng quan trọng trong lúc truy cập endpoint của bài hát để lấy dữ liệu. Tuy nhiên, sau khi đã lấy được dữ liệu, ta chỉ cần các thông số của bài nhạc, còn những thuộc tính này có thể bỏ đi.

# %%
df = df.drop(columns = ['type', 'uri', 'track_href', 'analysis_url'])

# %%
df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.507   0.394    6    -7.188     0       0.0350        0.5080
# 1            0.842   0.734    1    -5.065     0       0.0588        0.0427
# 2            0.759   0.561    0    -5.643     0       0.1310        0.8030
# 3            0.724   0.631    4    -4.420     0       0.0686        0.2490
# 4            0.765   0.356   11    -5.556     0       0.1950        0.2230
# ...            ...     ...  ...       ...   ...          ...           ...
# 1525         0.491   0.693    0    -6.487     0       0.0377        0.2110
# 1526         0.687   0.792    5    -2.749     1       0.0452        0.1910
# 1527         0.932   0.457   11    -9.620     0       0.0541        0.0173
# 1529         0.294   0.641   11    -9.316     1       0.0291        0.0163
# 1530         0.784   0.826    7    -6.340     0       0.0538        0.0965
#
#       instrumentalness  liveness  valence  ...  time_signature popularity  \
# 0             0.000000    0.0825    0.164  ...               4         85
# 1             0.000000    0.1060    0.952  ...               4         81
# 2             0.121000    0.1010    0.491  ...               4         82
# 3             0.000000    0.2130    0.957  ...               4         82
# 4             0.000000    0.0963    0.189  ...               4         86
# ...                ...       ...      ...  ...             ...        ...
# 1525          0.000007    0.3250    0.412  ...               4         85
# 1526          0.000000    0.1670    0.671  ...               4         86
# 1527          0.043600    0.0414    0.884  ...               4         81
# 1529          0.220000    0.1120    0.226  ...               4         82
# 1530          0.000071    0.1230    0.893  ...               3         81
#
#                  song_name      artist_name  genius_id  \
# 0      Shot Glass of Tears        Jung Kook    9626003
# 1                   Sucker   Jonas Brothers    4350998
# 2             VISTA AL MAR          Quevedo    8357473
# 3                    WANDA          Quevedo    8719683
# 4                    Don't    Bryson Tiller     579968
# ...                    ...              ...        ...
# 1525  Hymn for the Weekend         Coldplay    2353271
# 1526               Happier       Marshmello    3792450
# 1527           Billie Jean  Michael Jackson       1644
# 1529         November Rain    Guns N' Roses      84547
# 1530                   PRC       Peso Pluma    8736705
#
#                                                   lyric  tags  tier  \
# 0      Tell me, am I ever gonna feel again? Tell me,...   pop     C
# 1      We go together Better than birds of a feather...   pop     D
# 2      BlueFire Rápido llega' y rápido te vas (Vas) ...   pop     E
# 3      O-O-Ovy On The Drums Es usted o nadie, ¿oyó? ...   pop     E
# 4      Don't, don't play with her, don't be dishones...   r-b     C
# ...                                                 ...   ...   ...
# 1525   And said drink from me, drink from me (Oh-ah-...   r-b     C
# 1526   Lately, I've been, I've been thinking I want ...   pop     D
# 1527   She was more like a beauty queen from a movie...   pop     C
# 1529   When I look into your eyes I can see a love r...  rock     D
# 1530   Me levanto, un baño y luego me pongo a forjar...   pop     D
#
#                                              genius_url released_year
# 0     https://genius.com/Jung-kook-shot-glass-of-tea...        2023.0
# 1       https://genius.com/Jonas-brothers-sucker-lyrics        2019.0
# 2        https://genius.com/Quevedo-vista-al-mar-lyrics        2022.0
# 3               https://genius.com/Quevedo-wanda-lyrics        2023.0
# 4          https://genius.com/Bryson-tiller-dont-lyrics        2014.0
# ...                                                 ...           ...
# 1525  https://genius.com/Coldplay-hymn-for-the-weeke...        2016.0
# 1526  https://genius.com/Marshmello-and-bastille-hap...        2018.0
# 1527  https://genius.com/Michael-jackson-billie-jean...        1982.0
# 1529  https://genius.com/Guns-n-roses-november-rain-...        1991.0
# 1530  https://genius.com/Peso-pluma-and-natanael-can...        2023.0
#
# [1453 rows x 23 columns]

# %%
df.to_csv("processed_data.csv",index=False)
